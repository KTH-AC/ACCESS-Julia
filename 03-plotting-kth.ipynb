# %%
using Colors

kthcolorpalette = [colorant"#1954a6"; colorant"#9d102d";
    colorant"#62922e"; colorant"#24a0d8"; colorant"#e4363e";
    colorant"#b0c92b"; colorant"#fab919"; colorant"#d85497";
    colorant"#65656c"; colorant"#bdbcbc"; colorant"#e3e5e3"]
# Out:
# 11-element Array{ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}},1}:
#  RGB{N0f8}(0.098,0.329,0.651)
#  RGB{N0f8}(0.616,0.063,0.176)
#  RGB{N0f8}(0.384,0.573,0.18)
#  RGB{N0f8}(0.141,0.627,0.847)
#  RGB{N0f8}(0.894,0.212,0.243)
#  RGB{N0f8}(0.69,0.788,0.169)
#  RGB{N0f8}(0.98,0.725,0.098)
#  RGB{N0f8}(0.847,0.329,0.592)
#  RGB{N0f8}(0.396,0.396,0.424)
#  RGB{N0f8}(0.741,0.737,0.737)
#  RGB{N0f8}(0.89,0.898,0.89)

# %%
using Plots
pyplot(color_palette = kthcolorpalette)
# Out:
# Plots.PyPlotBackend()

# %%
plot(randn(100,8), layout = (4,2), color = [1 4 2 5 3 6 7 8], lab = ["\$y_{$n}\$" for row = 1:1, n in 1:8])
# Out:
# <img src="data:image/png;base64,..." />
